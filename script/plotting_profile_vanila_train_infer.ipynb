# %%
import numpy as np
import os 
import re
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
root = os.environ['HOME']
file = '../paper/profile_vanila_train.csv'
train = pd.read_csv(file, index_col =None)
train_avg = train.mean(axis =0)
print(train_avg)
train
# Out:
# GPU utilization %         38.770000
# GPU frequency (kHz)     1843.943333
# GPU power (W)            205.573333
# GPU temperature (°C)      57.630000
# dtype: float64
# /tmp/ipykernel_49638/2129172720.py:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train_avg = train.mean(axis =0)
#                   Model  GPU utilization %  GPU frequency (kHz)  \
# 0  EfficientNetV2-Large              82.54              1914.93
# 1     MobileNetV3-Small               4.56              1755.00
# 2              ResNet50              29.21              1861.90
#
#    GPU power (W)  GPU temperature (°C)
# 0         306.75                 65.00
# 1         119.36                 50.42
# 2         190.61                 57.47

# %%
file = '../paper/profile_vanila_infer.csv'
infer = pd.read_csv(file, index_col =None)
infer_avg = infer.mean(axis =0)
print(infer_avg)
# infer
# Out:
# GPU utilization %         18.94125
# GPU frequency (kHz)     1781.79125
# GPU power (W)            136.51125
# GPU temperature (°C)      50.00375
# dtype: float64
# /tmp/ipykernel_49638/3531124588.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   infer_avg = infer.mean(axis =0)

# %%
train_values = [38.8, 57.6, 205.6, 1843.9]
cols =['GPU utilization %', 'GPU frequency (kHz)', 'GPU power (W)','GPU temperature (°C)']
fig, ax = plt.subplots(figsize=(8, 3.5))
width = 0.5
colors = ['deepskyblue', 'goldenrod','lightcoral','green']

ax.bar(1, train_avg[cols[0]], width =width , color=colors[0])
ax.set_ylabel('GPU utilization %\n GPU temperature (°C)\n GPU power (W)', fontsize = 14)
# ax.set_xlabel('x')
ax.bar(2, train_avg[cols[3]], width =width , color=colors[1])
ax.bar(3, train_avg[cols[2]],width =width , color=colors[2])
ax.spines['right'].set_visible(False)
plt.legend(['GPU utilization','GPU temperature','GPU power'],loc=2, fontsize = 12)
for k in range(3):  ## plot first 3 columns
    plt.text(k+0.85, train_values[k]+8, train_values[k], fontsize =12)
plt.ylim(0,300)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

ax2 = ax.twinx()
ax2.bar(5, train_avg[cols[1]], width =width , color=colors[3])
ax2.set_ylabel('GPU frequency (kHz)',fontsize = 14)
plt.ylim(0,2200)
plt.legend(['GPU frequency'],loc=1, fontsize = 12)
k=3
plt.text(k+1.78, train_values[k]+50, train_values[k], fontsize =12)
plt.ylim(0,2400)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

# plt.title('GPU utilization of training tasks',  fontsize = 14)
plt.savefig('../paper/images/util_train.pdf',dpi=600, bbox_inches='tight')

# %%
## cols =['GPU utilization %', 'GPU frequency (kHz)', 'GPU power (W)','GPU temperature (°C)']
infer_values =[18.9, 50.0, 136.5, 1781.8]

fig, ax = plt.subplots(figsize=(8, 3.5))
width = 0.5
colors = ['deepskyblue', 'goldenrod','lightcoral','green']

ax.bar(1, infer_avg[cols[0]], width =width , color=colors[0])
ax.set_ylabel('GPU utilization %\n GPU temperature (°C)\n GPU power (W)', fontsize = 14)
# ax.set_xlabel('x')
ax.bar(2, infer_avg[cols[3]], width =width , color=colors[1])
ax.bar(3, infer_avg[cols[2]],width =width , color=colors[2])
ax.spines['right'].set_visible(False)
plt.legend(['GPU utilization','GPU temperature','GPU power'],loc=2, fontsize = 12)
for k in range(3):  ## plot first 3 columns
    plt.text(k+0.85, infer_values[k]+8, infer_values[k], fontsize =12)
plt.ylim(0,300)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

ax2 = ax.twinx()
ax2.bar(5, infer_avg[cols[1]], width =width , color=colors[3])
ax2.set_ylabel('GPU frequency (kHz)', fontsize = 14)
plt.legend(['GPU frequency'],loc=1, fontsize = 12)
k=3
plt.text(k+1.78, infer_values[k]+50, infer_values[k], fontsize =12)  ## plot last column
plt.ylim(0,2400)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
# plt.title('GPU utilization of inference tasks',  fontsize = 14)
plt.savefig('../paper/images/util_infer.pdf',dpi=600, bbox_inches='tight')

# %% [markdown]
# ## backup

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Aug 30 12:01:46 2022

@author: EpH
"""

import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1, 10, 0.01)
y = np.sin(2*x)
z = x**2
k = x**3

fig, ax = plt.subplots()
ax.plot(x, y, color='green')
ax.set_ylabel('y')
ax.set_xlabel('x')
ax.spines['right'].set_visible(False)

z_ax = ax.twinx()
z_ax.plot(x, z, color='blue')
z_ax.set_ylabel('z')

k_ax = ax.twinx()# 创建与轴群ax共享x轴的轴群k_ax
k_ax.spines['right'].set_position(('data', 12))# 确定k_ax轴群右边轴的位置在数值12
k_ax.plot(x, k, color='red')
k_ax.set_ylabel('k')

plt.show()

# %%
from mpl_toolkits.axisartist.parasite_axes import HostAxes, ParasiteAxes
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure() 
ax_cof = HostAxes(fig, [0, 0, 0.9, 0.9])  #用[left, bottom, weight, height]的方式定义axes，0 <= l,b,w,h <= 1

#parasite addtional axes, share x
ax_temp = ParasiteAxes(ax_cof, sharex=ax_cof)
ax_load = ParasiteAxes(ax_cof, sharex=ax_cof)
ax_cp = ParasiteAxes(ax_cof, sharex=ax_cof)
ax_wear = ParasiteAxes(ax_cof, sharex=ax_cof)

#append axes
ax_cof.parasites.append(ax_temp)
ax_cof.parasites.append(ax_load)
ax_cof.parasites.append(ax_cp)
ax_cof.parasites.append(ax_wear)

#invisible right axis of ax_cof
ax_cof.axis['right'].set_visible(False)
ax_cof.axis['top'].set_visible(False)
ax_temp.axis['right'].set_visible(True)
ax_temp.axis['right'].major_ticklabels.set_visible(True)
ax_temp.axis['right'].label.set_visible(True)

#set label for axis
ax_cof.set_ylabel('cof')
ax_cof.set_xlabel('Distance (m)')
ax_temp.set_ylabel('Temperature')
ax_load.set_ylabel('load')
ax_cp.set_ylabel('CP')
ax_wear.set_ylabel('Wear')

load_axisline = ax_load.get_grid_helper().new_fixed_axis
cp_axisline = ax_cp.get_grid_helper().new_fixed_axis
wear_axisline = ax_wear.get_grid_helper().new_fixed_axis

ax_load.axis['right2'] = load_axisline(loc='right', axes=ax_load, offset=(40,0))
ax_cp.axis['right3'] = cp_axisline(loc='right', axes=ax_cp, offset=(80,0))
ax_wear.axis['right4'] = wear_axisline(loc='right', axes=ax_wear, offset=(120,0))

fig.add_axes(ax_cof)

''' #set limit of x, y
ax_cof.set_xlim(0,2)
ax_cof.set_ylim(0,3)
'''

curve_cof, = ax_cof.plot([0, 1, 2], [0, 1, 2], label="CoF", color='black')
curve_temp, = ax_temp.plot([0, 1, 2], [0, 3, 2], label="Temp", color='red')
curve_load, = ax_load.plot([0, 1, 2], [1, 2, 3], label="Load", color='green')
curve_cp, = ax_cp.plot([0, 1, 2], [0, 40, 25], label="CP", color='pink')
curve_wear, = ax_wear.plot([0, 1, 2], [25, 18, 9], label="Wear", color='blue')

ax_temp.set_ylim(0,4)
ax_load.set_ylim(0,4)
ax_cp.set_ylim(0,50)
ax_wear.set_ylim(0,30)

ax_cof.legend()

#轴名称，刻度值的颜色
#ax_cof.axis['left'].label.set_color(ax_cof.get_color())
ax_temp.axis['right'].label.set_color('red')
ax_load.axis['right2'].label.set_color('green')
ax_cp.axis['right3'].label.set_color('pink')
ax_wear.axis['right4'].label.set_color('blue')

ax_temp.axis['right'].major_ticks.set_color('red')
ax_load.axis['right2'].major_ticks.set_color('green')
ax_cp.axis['right3'].major_ticks.set_color('pink')
ax_wear.axis['right4'].major_ticks.set_color('blue')

ax_temp.axis['right'].major_ticklabels.set_color('red')
ax_load.axis['right2'].major_ticklabels.set_color('green')
ax_cp.axis['right3'].major_ticklabels.set_color('pink')
ax_wear.axis['right4'].major_ticklabels.set_color('blue')

ax_temp.axis['right'].line.set_color('red')
ax_load.axis['right2'].line.set_color('green')
ax_cp.axis['right3'].line.set_color('pink')
ax_wear.axis['right4'].line.set_color('blue')

plt.show()
