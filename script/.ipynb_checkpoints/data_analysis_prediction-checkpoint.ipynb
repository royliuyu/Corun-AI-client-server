# %% [markdown]
# ## Latency prediction under training inference co-working

# %% [markdown]
# ### I. data preparation

# %%
import pandas as pd
import numpy as np
import os
import re

def str2dict(file_name):
    arg_list = ['arch','workers', 'epochs','batch_size', 'image_size', 'device']
    config= file_name[0].split('+')
    train_args = re.findall(r'Train (.+)',config[0].strip())[0].split(' ')
    infer_args = re.findall(r'Infer (.+)',config[1].strip())[0].split(' ')
    train_dict ={}
    infer_dict ={}
    for arg in arg_list:
        for arg_val in train_args:
            if re.match(arg, arg_val):
                val = re.findall(arg+'_(.+)', arg_val)[0]
                train_dict[arg]=val
        for arg_val in infer_args:
            if re.match(arg, arg_val):
                val = re.findall(arg+'_(.+)', arg_val)[0]
                infer_dict[arg]=val
    return train_dict, infer_dict
# train_dict, infer_dict = str2dict(file_name)
# print(train_dict, infer_dict)

def dict_str2value(dict_old):
    model_list =  ['deeplab_v3', 'yolo_v5s', 'alexnet','densenet201','mobilenet_v2','resnet152','shufflenet_v2_x1_0', 'squeezenet1_0', 'vgg16']
    model_map = {}
    for i, model_name in enumerate(model_list): model_map[model_name] = i
    dict_new ={}
    for arg, val in dict_old.items():
        if arg=='arch':
            dict_new['arch']=model_map[val]
        elif arg == 'device':
            dict_new['device']= 1 if dict_old['device'] == 'cuda' else 0
        else: 
            dict_new[arg] = int(val)
    return dict_new

def dict_str2value_partial(dict_old):
    model_list =  ['deeplab_v3', 'yolo_v5', 'alexnet','densenet201','mobilenet_v2','resnet152','shufflenet_v2_x1_0', 'squeezenet1_0', 'vgg16']
    model_map = {}
    for i, model_name in enumerate(model_list): model_map[model_name] = i
    dict_new ={}
    for arg, val in dict_old.items():
        if arg=='arch':
            dict_new['arch']=val
        elif arg == 'device':
            dict_new['device']= val
        else: 
            dict_new[arg] = int(val)
            dict_new[arg] = int(val)
    return dict_new

## columns to be added
train_col = ['arch', 'workers', 'epochs', 'batch_size', 'image_size', 'device']
infer_col = ['arch', 'workers', 'batch_size', 'image_size', 'device']
trn_col, inf_col =[], []
for col in train_col: trn_col.append('trn_'+col)
for col in infer_col: inf_col.append('inf_'+col)
add_col= trn_col+inf_col+['latency']
print(add_col)
# Out:
# ['trn_arch', 'trn_workers', 'trn_epochs', 'trn_batch_size', 'trn_image_size', 'trn_device', 'inf_arch', 'inf_workers', 'inf_batch_size', 'inf_image_size', 'inf_device', 'latency']

# %%
## consolidate log's below folder's 

#logfile
log= pd.read_csv('./data/profiler_log_20230123200614.csv')
root ='./data'

def parse_config(root, data_type, log_file):
    folder =os.path.join(root,'./',data_type)
    for file_name in os.listdir(folder):
        data =  pd.read_csv(os.path.join(folder,file_name))
    #     print(col)
        _file_name= re.findall(r'(.+)_20.+.csv', file_name)  # extract file name prefix
        train_dict, infer_dict = str2dict(_file_name)
        _train_dict = dict_str2value_partial(train_dict)  # change str to value, e.g. workers:'1'  to workers:1
        _infer_dict = dict_str2value_partial(infer_dict)
        record = log.where((log['train_configure']==str(_train_dict)) & \
                           (log['infer_configure']==str(_infer_dict))).dropna()
        result = record['result'].to_list()[0] # convert serial to list to string
        result = re.findall(r'{(.+)}', result)[0]  # extract string in { }
        latency = float(result.split(':')[1])
        train_dict_value = dict_str2value(train_dict)
        infer_dict_value = dict_str2value(infer_dict)
        values = list(train_dict_value.values())+list(infer_dict_value.values())+[latency]
        data_new= data.copy()
        for i, col in enumerate(add_col):
            for j in range(len(data)):  # repeatedly add 500 instances
                data_new[col]=values[i]
        data_new.to_csv(os.path.join(root,data_type+'_data.csv'), index_label=None, mode='a')
        print(f'Configure values of {data_type} : {values}.')

for data_type in ['train', 'val','test']:
    parse_config(root, data_type, log)
print('Data generated!')
# Out:
# Configure values of train : [2, 1, 3, 512, 224, 1, 1, 1, 1, 448, 1, 23.510233028418114].
# Configure values of train : [7, 1, 3, 32, 224, 1, 2, 1, 1, 448, 1, 2.89403568667342].
# Configure values of train : [2, 1, 3, 16, 224, 1, 2, 1, 1, 448, 1, 2.914940568388914].
# Configure values of train : [3, 1, 3, 1, 224, 1, 1, 1, 1, 448, 1, 24.672791567055185].
# Configure values of train : [2, 1, 3, 128, 224, 1, 2, 1, 1, 448, 1, 2.8583373110605264].
# Configure values of train : [0, 1, 3, 8, 224, 1, 2, 1, 1, 448, 1, 2.963675806669439].
# Configure values of train : [6, 1, 3, 4, 224, 1, 1, 1, 1, 448, 1, 23.904011934979465].
# Configure values of train : [8, 1, 3, 64, 224, 1, 2, 1, 1, 448, 1, 3.552546609068063].
# Configure values of train : [6, 1, 3, 32, 224, 1, 2, 1, 1, 448, 1, 2.812828712639261].
# Configure values of train : [2, 1, 3, 32, 224, 1, 1, 1, 1, 448, 1, 22.72914054113741].
# Configure values of train : [6, 1, 3, 64, 224, 1, 1, 1, 1, 448, 1, 23.758347213230604].
# Configure values of train : [7, 1, 3, 2, 224, 1, 2, 1, 1, 448, 1, 2.7913442975655176].
# Configure values of train : [4, 1, 3, 1, 224, 1, 2, 1, 1, 448, 1, 2.8069941348468137].
# Configure values of train : [7, 1, 3, 64, 224, 1, 1, 1, 1, 448, 1, 23.695303286936607].
# Configure values of train : [2, 1, 3, 1024, 224, 1, 2, 1, 1, 448, 1, 2.869002933988452].
# Configure values of train : [3, 1, 3, 32, 224, 1, 1, 1, 1, 448, 1, 25.987945155485427].
# Configure values of train : [3, 1, 3, 32, 224, 1, 2, 1, 1, 448, 1, 3.2869671003226215].
# Configure values of train : [6, 1, 3, 128, 224, 1, 2, 1, 1, 448, 1, 2.851877712210618].
# Configure values of train : [7, 1, 3, 128, 224, 1, 1, 1, 1, 448, 1, 24.05377920442206].
# Configure values of train : [2, 1, 3, 64, 224, 1, 1, 1, 1, 448, 1, 22.940928381546016].
# Configure values of train : [7, 1, 3, 1, 224, 1, 2, 1, 1, 448, 1, 2.850027861670906].
# Configure values of train : [2, 1, 3, 256, 224, 1, 1, 1, 1, 448, 1, 23.074793909515147].
# Configure values of train : [4, 1, 3, 32, 224, 1, 1, 1, 1, 448, 1, 24.22449557088945].
# Configure values of train : [3, 1, 3, 2, 224, 1, 2, 1, 1, 448, 1, 2.806708444872988].
# Configure values of train : [3, 1, 3, 1, 224, 1, 2, 1, 1, 448, 1, 2.7907746323318103].
# Configure values of train : [2, 1, 3, 64, 224, 1, 2, 1, 1, 448, 1, 2.8323339801912706].
# Configure values of train : [6, 1, 3, 4, 224, 1, 2, 1, 1, 448, 1, 2.7300352308683196].
# Configure values of train : [8, 1, 3, 32, 224, 1, 2, 1, 1, 448, 1, 3.527469146967188].
# Configure values of train : [4, 1, 3, 64, 224, 1, 1, 1, 1, 448, 1, 24.3384920847183].
# Configure values of train : [2, 1, 3, 256, 224, 1, 2, 1, 1, 448, 1, 2.822004654091595].
# Configure values of train : [2, 1, 3, 2, 224, 1, 2, 1, 1, 448, 1, 2.9274095520346695].
# Configure values of train : [2, 1, 3, 2, 224, 1, 1, 1, 1, 448, 1, 22.577425761165284].
# Configure values of train : [0, 1, 3, 4, 224, 1, 1, 1, 1, 448, 1, 25.476056914828913].
# Configure values of train : [2, 1, 3, 4, 224, 1, 2, 1, 1, 448, 1, 2.924458459553681].
# Configure values of train : [3, 1, 3, 4, 224, 1, 2, 1, 1, 448, 1, 2.838415030444248].
# Configure values of train : [2, 1, 3, 8, 224, 1, 2, 1, 1, 448, 1, 2.9275447713087326].
# Configure values of train : [6, 1, 3, 16, 224, 1, 1, 1, 1, 448, 1, 23.596322023843065].
# Configure values of train : [7, 1, 3, 128, 224, 1, 2, 1, 1, 448, 1, 2.9122733306663253].
# Configure values of train : [8, 1, 3, 64, 224, 1, 1, 1, 1, 448, 1, 30.260472187701335].
# Configure values of train : [3, 1, 3, 16, 224, 1, 1, 1, 1, 448, 1, 24.752304133008366].
# Configure values of train : [4, 1, 3, 64, 224, 1, 2, 1, 1, 448, 1, 2.968949907911629].
# Configure values of train : [8, 1, 3, 16, 224, 1, 1, 1, 1, 448, 1, 29.472812421475897].
# Configure values of train : [4, 1, 3, 32, 224, 1, 2, 1, 1, 448, 1, 2.9228491045857434].
# Configure values of train : [3, 1, 3, 16, 224, 1, 2, 1, 1, 448, 1, 3.029403192746901].
# Configure values of train : [6, 1, 3, 1, 224, 1, 1, 1, 1, 448, 1, 24.883113044857296].
# Configure values of train : [0, 1, 3, 4, 224, 1, 2, 1, 1, 448, 1, 2.8935822053555476].
# Configure values of train : [3, 1, 3, 2, 224, 1, 1, 1, 1, 448, 1, 24.526103253659176].
# Configure values of train : [6, 1, 3, 8, 224, 1, 2, 1, 1, 448, 1, 2.783377135666695].
# Configure values of train : [4, 1, 3, 16, 224, 1, 2, 1, 1, 448, 1, 2.904634501708755].
# Configure values of train : [7, 1, 3, 2, 224, 1, 1, 1, 1, 448, 1, 22.524730543995545].
# Configure values of train : [2, 1, 3, 1024, 224, 1, 1, 1, 1, 448, 1, 23.368535086913422].
# Configure values of train : [0, 1, 3, 8, 224, 1, 1, 1, 1, 448, 1, 24.58927581378013].
# Configure values of train : [3, 1, 3, 4, 224, 1, 1, 1, 1, 448, 1, 24.955896942677885].
# Configure values of train : [0, 1, 3, 1, 224, 1, 2, 1, 1, 448, 1, 2.943578914913518].
# Configure values of train : [7, 1, 3, 32, 224, 1, 1, 1, 1, 448, 1, 23.673803282501595].
# Configure values of train : [4, 1, 3, 16, 224, 1, 1, 1, 1, 448, 1, 23.63651454252781].
# Configure values of train : [2, 1, 3, 4, 224, 1, 1, 1, 1, 448, 1, 22.744762993619762].
# Configure values of train : [6, 1, 3, 8, 224, 1, 1, 1, 1, 448, 1, 23.46588926816996].
# Configure values of train : [7, 1, 3, 1, 224, 1, 1, 1, 1, 448, 1, 24.84657278654453].
# Configure values of train : [6, 1, 3, 256, 224, 1, 2, 1, 1, 448, 1, 2.8624269090099603].
# Configure values of train : [6, 1, 3, 32, 224, 1, 1, 1, 1, 448, 1, 23.309548489512792].
# Configure values of train : [2, 1, 3, 16, 224, 1, 3, 1, 1, 448, 1, 26.836365250171156].
# Configure values of train : [4, 1, 3, 1, 224, 1, 1, 1, 1, 448, 1, 24.669998132603187].
# Configure values of train : [5, 1, 3, 16, 224, 1, 2, 1, 1, 448, 1, 3.349096764023256].
# Configure values of train : [2, 1, 3, 32, 224, 1, 2, 1, 1, 448, 1, 2.859518492172853].
# Configure values of train : [4, 1, 3, 32, 224, 1, 3, 1, 1, 448, 1, 26.725220285825838].
# Configure values of train : [6, 1, 3, 128, 224, 1, 1, 1, 1, 448, 1, 23.846242366640205].
# Configure values of train : [6, 1, 3, 64, 224, 1, 2, 1, 1, 448, 1, 2.8584358097358704].
# Configure values of train : [8, 1, 3, 32, 224, 1, 1, 1, 1, 448, 1, 29.91739760656487].
# Configure values of train : [7, 1, 3, 16, 224, 1, 1, 1, 1, 448, 1, 23.273679514870267].
# Configure values of train : [6, 1, 3, 256, 224, 1, 1, 1, 1, 448, 1, 23.236731638961196].
# Configure values of train : [4, 1, 3, 2, 224, 1, 1, 1, 1, 448, 1, 23.260344042775266].
# Configure values of train : [4, 1, 3, 8, 224, 1, 1, 1, 1, 448, 1, 23.410203816073256].
# Configure values of train : [0, 1, 3, 2, 224, 1, 1, 1, 1, 448, 1, 22.438625950322923].
# Configure values of train : [2, 1, 3, 512, 224, 1, 2, 1, 1, 448, 1, 2.8555137063685483].
# Configure values of train : [7, 1, 3, 8, 224, 1, 1, 1, 1, 448, 1, 23.584347936544006].
# Configure values of train : [5, 1, 3, 32, 224, 1, 1, 1, 1, 448, 1, 29.926426691182858].
# Configure values of train : [7, 1, 3, 64, 224, 1, 2, 1, 1, 448, 1, 2.9526817496433493].
# Configure values of train : [0, 1, 3, 1, 224, 1, 1, 1, 1, 448, 1, 25.464385237126535].
# Configure values of train : [6, 1, 3, 1, 224, 1, 2, 1, 1, 448, 1, 2.7914835947994368].
# Configure values of train : [4, 1, 3, 8, 224, 1, 2, 1, 1, 448, 1, 2.838579399482706].
# Configure values of train : [6, 1, 3, 2, 224, 1, 1, 1, 1, 448, 1, 23.99694398715395].
# Configure values of train : [6, 1, 3, 2, 224, 1, 2, 1, 1, 448, 1, 2.7791031038635277].
# Configure values of train : [7, 1, 3, 4, 224, 1, 1, 1, 1, 448, 1, 23.37554844880329].
# Configure values of train : [4, 1, 3, 4, 224, 1, 1, 1, 1, 448, 1, 23.61631435335918].
# Configure values of train : [8, 1, 3, 16, 224, 1, 2, 1, 1, 448, 1, 3.519529190962818].
# Configure values of train : [2, 1, 3, 16, 224, 1, 1, 1, 1, 448, 1, 23.28622797477677].
# Configure values of train : [7, 1, 3, 16, 224, 1, 2, 1, 1, 448, 1, 2.903472045824274].
# Configure values of train : [5, 1, 3, 1, 224, 1, 1, 1, 1, 448, 1, 25.13744734702863].
# Configure values of train : [5, 1, 3, 16, 224, 1, 1, 1, 1, 448, 1, 27.623169500920653].
# Configure values of train : [3, 1, 3, 8, 224, 1, 2, 1, 1, 448, 1, 2.862094749849751].
# Configure values of train : [7, 1, 3, 4, 224, 1, 2, 1, 1, 448, 1, 2.8107388093024355].
# Configure values of train : [4, 1, 3, 4, 224, 1, 2, 1, 1, 448, 1, 2.7748955460559532].
# Configure values of train : [6, 1, 3, 16, 224, 1, 2, 1, 1, 448, 1, 2.8331670870027335].
# Configure values of train : [4, 1, 3, 2, 224, 1, 2, 1, 1, 448, 1, 2.817234575726354].
# Configure values of train : [7, 1, 3, 8, 224, 1, 2, 1, 1, 448, 1, 2.866928881829314].
# Configure values of train : [2, 1, 3, 128, 224, 1, 1, 1, 1, 448, 1, 22.970093707410435].
# Configure values of train : [2, 1, 3, 8, 224, 1, 1, 1, 1, 448, 1, 23.19533012323921].
# Configure values of train : [5, 1, 3, 32, 224, 1, 2, 1, 1, 448, 1, 3.571200511758963].
# Configure values of train : [0, 1, 3, 2, 224, 1, 2, 1, 1, 448, 1, 2.8497509916516326].
# Configure values of val : [4, 1, 3, 64, 224, 1, 3, 1, 1, 448, 1, 26.76214380845985].
# Configure values of val : [5, 1, 3, 1, 224, 1, 2, 1, 1, 448, 1, 2.791883906195571].
# Configure values of val : [4, 1, 3, 4, 224, 1, 3, 1, 1, 448, 1, 27.19743642700613].
# Configure values of val : [6, 1, 3, 8, 224, 1, 3, 1, 1, 448, 1, 26.89868656928938].
# Configure values of val : [5, 1, 3, 8, 224, 1, 1, 1, 1, 448, 1, 25.543899469233047].
# Configure values of val : [3, 1, 3, 8, 224, 1, 1, 1, 1, 448, 1, 24.860832114719308].
# Configure values of val : [8, 1, 3, 8, 224, 1, 1, 1, 1, 448, 1, 29.491272549828732].
# Configure values of val : [2, 1, 3, 8, 224, 1, 3, 1, 1, 448, 1, 27.19907014571503].
# Configure values of val : [2, 1, 3, 64, 224, 1, 3, 1, 1, 448, 1, 26.428322118752654].
# Configure values of val : [2, 1, 3, 512, 224, 1, 3, 1, 1, 448, 1, 26.384737344508494].
# Configure values of val : [2, 1, 3, 32, 224, 1, 3, 1, 1, 448, 1, 26.781155843862653].
# Configure values of val : [2, 1, 3, 256, 224, 1, 3, 1, 1, 448, 1, 26.3841641370632].
# Configure values of val : [0, 1, 3, 2, 224, 1, 3, 1, 1, 448, 1, 27.000136232705028].
# Configure values of val : [3, 1, 3, 16, 224, 1, 3, 1, 1, 448, 1, 27.216031501838295].
# Configure values of val : [2, 1, 3, 1024, 224, 1, 3, 1, 1, 448, 1, 26.30184978192574].
# Configure values of val : [5, 1, 3, 2, 224, 1, 1, 1, 1, 448, 1, 24.596892737692322].
# Configure values of val : [4, 1, 3, 16, 224, 1, 3, 1, 1, 448, 1, 26.889838839637427].
# Configure values of val : [5, 1, 3, 4, 224, 1, 1, 1, 1, 448, 1, 25.5589691125876].
# Configure values of val : [5, 1, 3, 8, 224, 1, 2, 1, 1, 448, 1, 3.002698432793169].
# Configure values of val : [2, 1, 3, 128, 224, 1, 3, 1, 1, 448, 1, 26.665647365987663].
# Configure values of val : [2, 1, 3, 4, 224, 1, 3, 1, 1, 448, 1, 27.598338185319996].
# Configure values of val : [6, 1, 3, 4, 224, 1, 3, 1, 1, 448, 1, 26.796536838771587].
# Configure values of val : [4, 1, 3, 8, 224, 1, 3, 1, 1, 448, 1, 26.807793488569246].
# Configure values of val : [3, 1, 3, 32, 224, 1, 3, 1, 1, 448, 1, 27.297812248776633].
# Configure values of val : [6, 1, 3, 2, 224, 1, 3, 1, 1, 448, 1, 27.43589112278407].
# Configure values of val : [8, 1, 3, 8, 224, 1, 2, 1, 1, 448, 1, 3.537408213541745].
# Configure values of val : [3, 1, 3, 1, 224, 1, 3, 1, 1, 448, 1, 26.159032029935272].
# Configure values of val : [5, 1, 3, 4, 224, 1, 2, 1, 1, 448, 1, 2.8244956309033498].
# Configure values of test : [2, 1, 3, 1, 224, 1, 2, 1, 1, 448, 1, 3.3249535613705024].
# Configure values of test : [8, 1, 3, 4, 224, 1, 1, 1, 1, 448, 1, 29.514703235985447].
# Configure values of test : [0, 1, 3, 8, 224, 1, 3, 1, 1, 448, 1, 26.423413593783327].
# Configure values of test : [5, 1, 3, 8, 224, 1, 3, 1, 1, 448, 1, 26.968048335590048].
# Configure values of test : [3, 1, 3, 2, 224, 1, 3, 1, 1, 448, 1, 26.297300936493034].
# Configure values of test : [8, 1, 3, 1, 224, 1, 2, 1, 1, 448, 1, 3.6633075783735918].
# Configure values of test : [5, 1, 3, 32, 224, 1, 3, 1, 1, 448, 1, 27.42181345224524].
# Configure values of test : [5, 1, 3, 16, 224, 1, 3, 1, 1, 448, 1, 27.213913057101877].
# Configure values of test : [3, 1, 3, 8, 224, 1, 3, 1, 1, 448, 1, 26.698635086991292].
# Configure values of test : [4, 1, 3, 1, 224, 1, 3, 1, 1, 448, 1, 26.077405186914323].
# Configure values of test : [2, 1, 3, 1, 224, 1, 3, 1, 1, 448, 1, 27.10473228013743].
# Configure values of test : [5, 1, 3, 2, 224, 1, 2, 1, 1, 448, 1, 2.787644933702792].
# Configure values of test : [4, 1, 3, 2, 224, 1, 3, 1, 1, 448, 1, 27.40938447633567].
# Configure values of test : [2, 1, 3, 1, 224, 1, 1, 1, 1, 448, 1, 28.683990437436364].
# Configure values of test : [8, 1, 3, 2, 224, 1, 2, 1, 1, 448, 1, 3.1559457113293616].
# Configure values of test : [3, 1, 3, 4, 224, 1, 3, 1, 1, 448, 1, 26.75045947145595].
# Configure values of test : [0, 1, 3, 1, 224, 1, 3, 1, 1, 448, 1, 26.771869154212418].
# Configure values of test : [8, 1, 3, 2, 224, 1, 1, 1, 1, 448, 1, 29.46310041928657].
# Configure values of test : [0, 1, 3, 4, 224, 1, 3, 1, 1, 448, 1, 26.39173870700294].
# Configure values of test : [8, 1, 3, 4, 224, 1, 2, 1, 1, 448, 1, 3.425025881065215].
# Configure values of test : [2, 1, 3, 2, 224, 1, 3, 1, 1, 448, 1, 27.73676541158934].
# Configure values of test : [5, 1, 3, 1, 224, 1, 3, 1, 1, 448, 1, 26.01155738511846].
# Configure values of test : [8, 1, 3, 1, 224, 1, 1, 1, 1, 448, 1, 38.10741483443442].
# Configure values of test : [5, 1, 3, 2, 224, 1, 3, 1, 1, 448, 1, 26.329494636638042].
# Configure values of test : [5, 1, 3, 4, 224, 1, 3, 1, 1, 448, 1, 26.835700672152626].
# Data generated!

# %% [markdown]
# ## II. data analysis

# %%
import pandas as pd
import numpy as np
import os
## load data 
dataset_train = pd.read_csv(os.path.join(root, 'train_data.csv'), index_col = None).iloc[:,2:]
dataset_train =  dataset_train.drop(['gpu_name', 'time_stamp','timestamp' ], axis=1)
dataset_val = pd.read_csv(os.path.join(root, 'val_data.csv'), index_col = None).iloc[:,2:] #[:,2:] filter unnamed cols
dataset_val =  dataset_val.drop(['gpu_name', 'time_stamp','timestamp' ], axis=1) 
dataset_test = pd.read_csv(os.path.join(root, 'test_data.csv'), index_col = None).iloc[:,2:]
dataset_test =  dataset_test.drop(['gpu_name', 'time_stamp','timestamp' ], axis=1)
dataset_train= dataset_train[dataset_train['gpu_power']!='gpu_power'].dropna()  # drop off rows of column names
dataset_val= dataset_val[dataset_val['gpu_power']!='gpu_power'].dropna()
dataset_test= dataset_test[dataset_test['gpu_power']!='gpu_power'].dropna()

y_train = dataset_train.iloc[:,-1]
x_train = dataset_train.iloc[:,:-1]
y_valid = dataset_val.iloc[:,-1]
x_valid = dataset_val.iloc[:,:-1]


for col in dataset_val.columns: 
    dataset_val[col] = pd.to_numeric( dataset_val[col])
for col in dataset_train.columns: 
    dataset_train[col] = pd.to_numeric( dataset_train[col])
    
print(dataset_val.columns)
print(dataset_train.iloc[0])

# view some data
# Out:
# Index(['gpu_power', 'gpu_freq', 'gpu_mem_freq', 'gpu_temp', 'gpu_util%',
#        'gpu_mem_util%', 'us', 'sy', 'ni', 'id', 'wa', 'hi', 'si', 'st',
#        'cpu0_freq', 'cpu1_freq', 'cpu2_freq', 'cpu3_freq', 'cpu4_freq',
#        'cpu5_freq', 'cpu6_freq', 'cpu7_freq', 'cpu8_freq', 'cpu9_freq',
#        'cpu10_freq', 'cpu11_freq', 'cpu12_freq', 'cpu13_freq', 'cpu14_freq',
#        'cpu15_freq', 'trn_arch', 'trn_workers', 'trn_epochs', 'trn_batch_size',
#        'trn_image_size', 'trn_device', 'inf_arch', 'inf_workers',
#        'inf_batch_size', 'inf_image_size', 'inf_device', 'latency'],
#       dtype='object')
# gpu_power         1.105100e+02
# gpu_freq          1.710000e+03
# gpu_mem_freq      9.251000e+03
# gpu_temp          4.500000e+01
# gpu_util%         5.000000e+00
# gpu_mem_util%     0.000000e+00
# us                8.100000e+01
# sy                4.900000e+00
# ni                0.000000e+00
# id                1.400000e+01
# wa                0.000000e+00
# hi                0.000000e+00
# si                0.000000e+00
# st                0.000000e+00
# cpu0_freq         1.687076e+06
# cpu1_freq         1.221107e+06
# cpu2_freq         1.304323e+06
# cpu3_freq         4.033043e+06
# cpu4_freq         2.082667e+06
# cpu5_freq         4.015601e+06
# cpu6_freq         1.279477e+06
# cpu7_freq         4.032016e+06
# cpu8_freq         2.120700e+06
# cpu9_freq         1.350404e+06
# cpu10_freq        1.482377e+06
# cpu11_freq        3.999865e+06
# cpu12_freq        1.989742e+06
# cpu13_freq        4.016914e+06
# cpu14_freq        1.263985e+06
# cpu15_freq        4.068138e+06
# trn_arch          2.000000e+00
# trn_workers       1.000000e+00
# trn_epochs        3.000000e+00
# trn_batch_size    5.120000e+02
# trn_image_size    2.240000e+02
# trn_device        1.000000e+00
# inf_arch          1.000000e+00
# inf_workers       1.000000e+00
# inf_batch_size    1.000000e+00
# inf_image_size    4.480000e+02
# inf_device        1.000000e+00
# latency           2.351023e+01
# Name: 0, dtype: float64

# %%
#coding:utf-8
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
import pandas as pd
import matplotlib.pyplot as plt

class data_utils():
    def __init__(self):
        pass

    def minmax_scale(self,dataset):

        min_max_scaler = MinMaxScaler()
        min_max_scaler.fit(dataset)
        dataset = min_max_scaler.transform(dataset)
        return dataset
 
    def minmax_scale_inverse(self,y_valid,y_new):

        min_max_scaler = MinMaxScaler()
        min_max_scaler.fit(y_valid)
        y_new_TURE = min_max_scaler.inverse_transform(y_new)
        return y_new_TURE

class neural_network():
    def __init__(self,epochs=5,batch_size=8,verbose=1,loss='mse',optimizer='adam'):
        self.epochs = epochs          
        self.batch_size = batch_size  
        self.verbose = verbose        
        self.loss = loss              
        self.optimizer = optimizer    

    def train_nn(self,x_train, y_train,x_valid, y_valid):

        model = Sequential()  
        model.add(Dense(units = 10,                      
                        activation='linear',             
                        input_shape=(x_train.shape[1],)  
                        ))
        model.add(Dropout(0.2))  
        model.add(Dense(units = 1,  activation='linear')) 
        model.compile(loss=self.loss,optimizer=self.optimizer,) 
        history = model.fit(x_train, y_train,  epochs=self.epochs, 
                            batch_size=self.batch_size, 
                            verbose=self.verbose, 
                            validation_data = (x_valid, y_valid)) 
 
        plt.title('Loss Curves')
        plt.ylabel('loss')
        plt.xlabel('epochs')
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.show()

        model.save('nn_model.h5') 

    def predict_nn(self,x_test):

        model = load_model('nn_model.h5')
        y_new = model.predict(x_test)
        return y_new

def main(dataset_train, dataset_val):

    du = data_utils()
    nn = neural_network()     

    y_train = dataset_train.iloc[:,-1].to_numpy().reshape(-1, 1)
    x_train = dataset_train.iloc[:,:-1].to_numpy()
    y_valid = dataset_val.iloc[:,-1].to_numpy().reshape(-1, 1)
    x_valid = dataset_val.iloc[:,:-1].to_numpy()
    
    x_train = du.minmax_scale(x_train)   
    y_train = du.minmax_scale(y_train)   
    x_valid = du.minmax_scale(x_valid)   
    y_valid = du.minmax_scale(y_valid)    

    nn.train_nn(x_train, y_train,x_valid, y_valid) 
    pre_new = nn.predict_nn(x_valid)               
    pre_new = du.minmax_scale_inverse(y_valid, pre_new) 

if __name__ == "__main__":
    main(dataset_train, dataset_val)
# Out:
# Epoch 1/5
# 12500/12500 [==============================] - 20s 2ms/step - loss: 0.0561 - val_loss: 0.1884
# Epoch 2/5
# 12500/12500 [==============================] - 19s 2ms/step - loss: 0.0240 - val_loss: 0.2287
# Epoch 3/5
# 12500/12500 [==============================] - 19s 2ms/step - loss: 0.0237 - val_loss: 0.2035
# Epoch 4/5
# 12500/12500 [==============================] - 19s 2ms/step - loss: 0.0234 - val_loss: 0.2486
# Epoch 5/5
# 12500/12500 [==============================] - 19s 2ms/step - loss: 0.0231 - val_loss: 0.2824

# %% [markdown]
# ### backup

# %%
## get inference time
import pandas as pd
log= pd.read_csv('./data/profiler_log.csv')
log
# Out:
#      Unnamed: 0    time_frame  \
# 0             1  1.674091e+09
# 1             2  1.674092e+09
# 2             3  1.674092e+09
# 3             4  1.674092e+09
# 4             5  1.674093e+09
# ..          ...           ...
# 229         230  1.674110e+09
# 230         231  1.674110e+09
# 231         232  1.674110e+09
# 232         233  1.674110e+09
# 233         234  1.674110e+09
#
#                                        train_configure  \
# 0    {'arch': 'deeplab_v3', 'workers': 1, 'epochs':...
# 1    {'arch': 'deeplab_v3', 'workers': 1, 'epochs':...
# 2    {'arch': 'deeplab_v3', 'workers': 1, 'epochs':...
# 3    {'arch': 'deeplab_v3', 'workers': 1, 'epochs':...
# 4    {'arch': 'alexnet', 'workers': 1, 'epochs': 3,...
# ..                                                 ...
# 229  {'arch': 'vgg16', 'workers': 1, 'epochs': 3, '...
# 230  {'arch': 'vgg16', 'workers': 1, 'epochs': 3, '...
# 231  {'arch': 'vgg16', 'workers': 1, 'epochs': 3, '...
# 232  {'arch': 'vgg16', 'workers': 1, 'epochs': 3, '...
# 233  {'arch': 'vgg16', 'workers': 1, 'epochs': 3, '...
#
#                                        infer_configure  status  \
# 0    {'arch': 'yolo_v5', 'workers': 1, 'batch_size'...  Sucess
# 1    {'arch': 'yolo_v5', 'workers': 1, 'batch_size'...  Sucess
# 2    {'arch': 'yolo_v5', 'workers': 1, 'batch_size'...  Sucess
# 3    {'arch': 'yolo_v5', 'workers': 1, 'batch_size'...    Fail
# 4    {'arch': 'yolo_v5', 'workers': 1, 'batch_size'...  Sucess
# ..                                                 ...     ...
# 229  {'arch': 'vgg16', 'workers': 1, 'batch_size': ...    Fail
# 230  {'arch': 'vgg16', 'workers': 1, 'batch_size': ...    Fail
# 231  {'arch': 'vgg16', 'workers': 1, 'batch_size': ...    Fail
# 232  {'arch': 'vgg16', 'workers': 1, 'batch_size': ...    Fail
# 233  {'arch': 'vgg16', 'workers': 1, 'batch_size': ...    Fail
#
#                                                 result
# 0                       {'latency': 16.18007766597196}
# 1                      {'latency': 15.969569237430791}
# 2                       {'latency': 16.01557815458632}
# 3    Traceback (most recent call last):\n  File "/h...
# 4                      {'latency': 14.060524985394178}
# ..                                                 ...
# 229  Traceback (most recent call last):\n  File "/h...
# 230  Traceback (most recent call last):\n  File "/h...
# 231  Traceback (most recent call last):\n  File "/h...
# 232  Traceback (most recent call last):\n  File "/h...
# 233  Traceback (most recent call last):\n  File "/h...
#
# [234 rows x 6 columns]

# %%
a="{'arch': 'alexnet', 'workers': 1, 'epochs': 3, 'batch_size': 128, 'image_size': 224, 'device': 'cuda'}"
b="{'arch': 'yolo_v5', 'workers': 1, 'batch_size': 1, 'image_size': 224, 'device': 'cuda'}"

# %%
{'arch': 'alexnet', 'workers': 1, 'epochs': 3, 'batch_size': 1024, 'image_size': 224, 'device': 'cuda'}
